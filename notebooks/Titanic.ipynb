# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D://Practice//TitanicDatasetDataCleaning//train.csv")
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop('Cabin', axis=1, inplace=True)
display(data)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data[['Age', 'Fare']] = data[['Age', 'Fare']].fillna(data[['Age', 'Fare']].mean())

data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.hist()
# Out:
# array([[<Axes: title={'center': 'PassengerId'}>,
#         <Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>,
#         <Axes: title={'center': 'Parch'}>],
#        [<Axes: title={'center': 'Fare'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
def gender_cleaning(x):
    if x=="male":
        return "M"
    else:
        return "F"

data["Sex"]= data["Sex"].apply(gender_cleaning)
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   M  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0      1      0
# 2                             Heikkinen, Miss. Laina   F  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0      1      0
# 4                           Allen, Mr. William Henry   M  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
grouped = data.groupby('Survived').size()

# %% [raw]
# print(grouped)

# %%
gender_survival = data.groupby('Sex')['Survived'].count()
gender_survival
# Out:
# Sex
# F    314
# M    577
# Name: Survived, dtype: int64

# %%
data[data['Survived']==1].count()
# Out:
# PassengerId    342
# Survived       342
# Pclass         342
# Name           342
# Sex            342
# Age            342
# SibSp          342
# Parch          342
# Ticket         342
# Fare           342
# Embarked       340
# dtype: int64

# %%
data[data['Survived']==0].count()
# Out:
# PassengerId     549
# Survived        549
# Pclass          549
# Sex             549
# Age             549
# SibSp           549
# Parch           549
# Ticket          549
# Fare            549
# Embarked        549
# First Name      549
# Last Name       549
# Age Division    549
# Fares           549
# dtype: int64

# %%
def seperate_names(x):
    first_name = x.split(',')[1].strip()
    last_name = x.split(',')[0].strip()
    return first_name, last_name

data[['First Name', 'Last Name']]= data['Name'].apply(seperate_names).apply(pd.Series)
data.drop('Name', axis = 1, inplace=True)
display(data)
# Out:
#      PassengerId  Survived  Pclass Sex        Age  SibSp  Parch  \
# 0              1         0       3   M  22.000000      1      0
# 1              2         1       1   F  38.000000      1      0
# 2              3         1       3   F  26.000000      0      0
# 3              4         1       1   F  35.000000      1      0
# 4              5         0       3   M  35.000000      0      0
# ..           ...       ...     ...  ..        ...    ...    ...
# 886          887         0       2   M  27.000000      0      0
# 887          888         1       1   F  19.000000      0      0
# 888          889         0       3   F  29.699118      1      2
# 889          890         1       1   M  26.000000      0      0
# 890          891         0       3   M  32.000000      0      0
#
#                Ticket     Fare Embarked  \
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# ...

# %%
class_survival = data[data['Survived']==1].groupby('Pclass')['Survived'].count()
print(class_survival)

class_groups = data.groupby('Pclass').size()
print(class_groups)
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
class_survival.plot(kind='pie',autopct='%1.1f%%', legend = True)
plt.title('Survival of people by their class basis')
plt.show()

# %%
def age_section(x):
    if x>18 and x<=40:
        return 'A'
    elif x<18:
        return 'Y'
    else:
        return 'O'
data[['Age Division']] = data['Age'].apply(age_section).apply(pd.Series)
display(data)
# Out:
#      PassengerId  Survived  Pclass Sex        Age  SibSp  Parch  \
# 0              1         0       3   M  22.000000      1      0
# 1              2         1       1   F  38.000000      1      0
# 2              3         1       3   F  26.000000      0      0
# 3              4         1       1   F  35.000000      1      0
# 4              5         0       3   M  35.000000      0      0
# ..           ...       ...     ...  ..        ...    ...    ...
# 886          887         0       2   M  27.000000      0      0
# 887          888         1       1   F  19.000000      0      0
# 888          889         0       3   F  29.699118      1      2
# 889          890         1       1   M  26.000000      0      0
# 890          891         0       3   M  32.000000      0      0
#
#                Ticket     Fare Embarked  \
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# ...

# %%
total_age = data.groupby('Age Division').size()
total_age.plot(kind='pie', legend = True, autopct='%1.1f%%', labels = [f'{x} {y}' for x, y in zip(total_age.index, total_age)])
plt.title('Total Age Distribution')
plt.show()

age_dist = data[data['Survived']==1].groupby('Age Division')['Survived'].count().plot(kind='pie', legend=True, autopct='%1.1f%%')
plt.title('Age wise distribution of Survivals')
plt.show()

# %%
embarked_group = data.groupby('Embarked').size()
embarked_group.plot(kind='pie', autopct='%1.1f%%', labels = [f'{x} {y}' for x, y in zip(embarked_group.index, embarked_group)])
plt.title('Embarked from which ports')
plt.show()

embarked_survived = data[data['Survived']==1].groupby('Embarked').size()
embarked_survived.plot(kind='pie', autopct='%1.1f%%', labels = [f'{x} {y}' for x, y in zip(embarked_survived.index, embarked_survived)])
plt.title('Survivals from different embarked ports')
plt.show()

# %%
ports_fare_range = data.groupby('Embarked')['Fare'].agg(lambda x: x.max() - x.min())

print(ports_fare_range)
# Plotting the range of fares for different ports
ports_fare_range.plot(kind='bar', figsize=(10, 6), color='orange')

plt.title('Range of Fare for People Embarked from Different Ports')
plt.xlabel('Embarkation Port')
plt.ylabel('Fare Range')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('range_of_fare.png', format='png', dpi=300)
plt.show()
# Out:
# Embarked
# C    508.3167
# Q     83.2500
# S    263.0000
# Name: Fare, dtype: float64

# %%
mean_fares = data.groupby('Embarked')['Fare'].mean()
data['Fares'] = data.apply( lambda row: mean_fares[row['Embarked']] if row['Fare']==0 else row['Fare'] , axis=1)
display(data)
# Out:
#      PassengerId  Survived  Pclass Sex        Age  SibSp  Parch  \
# 0              1         0       3   M  22.000000      1      0
# 1              2         1       1   F  38.000000      1      0
# 2              3         1       3   F  26.000000      0      0
# 3              4         1       1   F  35.000000      1      0
# 4              5         0       3   M  35.000000      0      0
# ..           ...       ...     ...  ..        ...    ...    ...
# 886          887         0       2   M  27.000000      0      0
# 887          888         1       1   F  19.000000      0      0
# 888          889         0       3   F  29.699118      1      2
# 889          890         1       1   M  26.000000      0      0
# 890          891         0       3   M  32.000000      0      0
#
#                Ticket     Fare Embarked  \
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# ...

# %%
data['Family_Size'] = data['SibSp'] + data['Parch']
display(data)
survival_by_family = data.groupby('Family_Size')['Survived'].mean()
print(
# Out:
#      PassengerId  Survived  Pclass Sex        Age  SibSp  Parch  \
# 0              1         0       3   M  22.000000      1      0
# 1              2         1       1   F  38.000000      1      0
# 2              3         1       3   F  26.000000      0      0
# 3              4         1       1   F  35.000000      1      0
# 4              5         0       3   M  35.000000      0      0
# ..           ...       ...     ...  ..        ...    ...    ...
# 886          887         0       2   M  27.000000      0      0
# 887          888         1       1   F  19.000000      0      0
# 888          889         0       3   F  29.699118      1      2
# 889          890         1       1   M  26.000000      0      0
# 890          891         0       3   M  32.000000      0      0
#
#                Ticket     Fare Embarked  \
# 0           A/5 21171   7.2500        S
# 1            PC 17599  71.2833        C
# 2    STON/O2. 3101282   7.9250        S
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(survival_by_family.index, survival_by_family.values, marker='o', linestyle='-', color='b')

plt.title('Impact of Family Size on Survival Rate')
plt.xlabel('Family Size')
plt.ylabel('Survival Rate')
plt.ylim(0, 1)
plt.xticks(survival_by_family.index) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('family_size_survival_rate.png', format='png', dpi=300)
# Display the plot
plt.show()
